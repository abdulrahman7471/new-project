# %%
import pandas as pd

# %%
pd.read_csv(filepath_or_buffer="sales (1) (2)1.xls")
# Out:
#         Order ID Order Date Customer ID  Product ID  Units Sold  Total Sales
# 0          15352  16-Mar-18       E1083          30           5        48.25
# 1           8156  11-Apr-18       E1086          63          10       100.00
# 2          48406  26-Jun-16       E1008          21          12       312.00
# 3          70967  24-Nov-17       E1076          40          40      3880.00
# 4          70148  12-Aug-16       E1047          72           9        81.00
# ...          ...        ...         ...         ...         ...          ...
# 106688     80929  11-Sep-15       E1069           6          80      1440.00
# 106689     67468  01-May-18       E1014          14          85       595.00
# 106690     75144  28-Sep-17       E1004          32          49       882.00
# 106691     77039  20-Aug-15       E1050          55          67      1005.00
# 106692     27085  15-Sep-16       E1071           6          66      1188.00
#
# [106693 rows x 6 columns]

# %%
order_deatils=pd.read_csv(filepath_or_buffer="sales (1) (2)1.xls")

# %%
order_deatils.head()
# Out:
#    Order ID Order Date Customer ID  Product ID  Units Sold  Total Sales
# 0     15352  16-Mar-18       E1083          30           5        48.25
# 1      8156  11-Apr-18       E1086          63          10       100.00
# 2     48406  26-Jun-16       E1008          21          12       312.00
# 3     70967  24-Nov-17       E1076          40          40      3880.00
# 4     70148  12-Aug-16       E1047          72           9        81.00

# %%
order_deatils.tail()
# Out:
#         Order ID Order Date Customer ID  Product ID  Units Sold  Total Sales
# 106688     80929  11-Sep-15       E1069           6          80       1440.0
# 106689     67468  01-May-18       E1014          14          85        595.0
# 106690     75144  28-Sep-17       E1004          32          49        882.0
# 106691     77039  20-Aug-15       E1050          55          67       1005.0
# 106692     27085  15-Sep-16       E1071           6          66       1188.0

# %%
order_deatils.head(10)
# Out:
#    Order ID Order Date Customer ID  Product ID  Units Sold  Total Sales
# 0     15352  16-Mar-18       E1083          30           5        48.25
# 1      8156  11-Apr-18       E1086          63          10       100.00
# 2     48406  26-Jun-16       E1008          21          12       312.00
# 3     70967  24-Nov-17       E1076          40          40      3880.00
# 4     70148  12-Aug-16       E1047          72           9        81.00
# 5     55712  21-Oct-17       E1043          54          35       271.25
# 6     29515  06-Jun-16       E1025          75          10       439.00
# 7     10798  15-Jun-15       E1089          73          15       450.00
# 8     66624  09-Feb-17       E1015          13           6        79.50
# 9     52344  09-Apr-15       E1071          72          20       180.00

# %%
order_deatils.head(20)
# Out:
#     Order ID Order Date Customer ID  Product ID  Units Sold  Total Sales
# 0      15352  16-Mar-18       E1083          30           5        48.25
# 1       8156  11-Apr-18       E1086          63          10       100.00
# 2      48406  26-Jun-16       E1008          21          12       312.00
# 3      70967  24-Nov-17       E1076          40          40      3880.00
# 4      70148  12-Aug-16       E1047          72           9        81.00
# 5      55712  21-Oct-17       E1043          54          35       271.25
# 6      29515  06-Jun-16       E1025          75          10       439.00
# 7      10798  15-Jun-15       E1089          73          15       450.00
# 8      66624  09-Feb-17       E1015          13           6        79.50
# 9      52344  09-Apr-15       E1071          72          20       180.00
# 10     44789  02-Aug-16       E1034          19          15       187.50
# 11     66297  10-Jul-16       E1032          75          25      1097.50
# ...

# %%
order_deatils.head(20)
# Out:
#     Order ID Order Date Customer ID  Product ID  Units Sold  Total Sales
# 0      15352  16-Mar-18       E1083          30           5        48.25
# 1       8156  11-Apr-18       E1086          63          10       100.00
# 2      48406  26-Jun-16       E1008          21          12       312.00
# 3      70967  24-Nov-17       E1076          40          40      3880.00
# 4      70148  12-Aug-16       E1047          72           9        81.00
# 5      55712  21-Oct-17       E1043          54          35       271.25
# 6      29515  06-Jun-16       E1025          75          10       439.00
# 7      10798  15-Jun-15       E1089          73          15       450.00
# 8      66624  09-Feb-17       E1015          13           6        79.50
# 9      52344  09-Apr-15       E1071          72          20       180.00
# 10     44789  02-Aug-16       E1034          19          15       187.50
# 11     66297  10-Jul-16       E1032          75          25      1097.50
# ...

# %%
order_deatils.tail(20)
# Out:
#         Order ID Order Date Customer ID  Product ID  Units Sold  Total Sales
# 106673     24099  10-Sep-15       E1032          44          10       140.00
# 106674     87422  14-Dec-18       E1059          56          23       218.50
# 106675     64974  30-Dec-15       E1047          71          40       298.00
# 106676     52521  04-Jan-16       E1024          73          32       960.00
# 106677     12477  25-Nov-16       E1064          26          10       210.00
# 106678     24844  27-Aug-18       E1026          32          71      1278.00
# 106679     16123  04-May-15       E1039          17          30       465.00
# 106680     54219  26-Oct-15       E1003          24          77      1497.65
# 106681     20944  09-Jun-16       E1076          52           9       495.00
# 106682     76301  17-Nov-16       E1040          74          87      1413.75
# 106683      5266  05-Oct-17       E1089          55          71      1065.00
# ...

# %%
order_deatils.shape
# Out:
# (106693, 6)

# %%
order_deatils.isna
# Out:
# <bound method DataFrame.isna of         Order ID Order Date Customer ID  Product ID  Units Sold  Total Sales
# 0          15352  16-Mar-18       E1083          30           5        48.25
# 1           8156  11-Apr-18       E1086          63          10       100.00
# 2          48406  26-Jun-16       E1008          21          12       312.00
# 3          70967  24-Nov-17       E1076          40          40      3880.00
# 4          70148  12-Aug-16       E1047          72           9        81.00
# ...          ...        ...         ...         ...         ...          ...
# 106688     80929  11-Sep-15       E1069           6          80      1440.00
# 106689     67468  01-May-18       E1014          14          85       595.00
# 106690     75144  28-Sep-17       E1004          32          49       882.00
# 106691     77039  20-Aug-15       E1050          55          67      1005.00
# 106692     27085  15-Sep-16       E1071           6          66      1188.00
#
# ...

# %%
order_deatils.dtypes
# Out:
# Order ID         int64
# Order Date      object
# Customer ID     object
# Product ID       int64
# Units Sold       int64
# Total Sales    float64
# dtype: object
